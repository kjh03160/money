# %%
import pandas as pd
from datetime import datetime

def df_in_dates(df, dates):
    start_date = datetime.strptime(dates[0], '%Y-%m-%d')
    end_date = datetime.strptime(dates[-1], '%Y-%m-%d') if len(dates) > 1 else start_date
    filtered = df.loc[(df['주문시각'] >= start_date) & (df['주문시각'] <= end_date)]
    return filtered

def menu_st(dates):

    nw = pd.read_csv('./data/now_waiting/Accumulated_data.csv', encoding='utf-8-sig')
    bm = pd.read_csv('./data/baemin/Accumulated_data.csv', encoding='utf-8-sig')

    nw['주문시각'] = pd.to_datetime(nw['주문시각'].str[:10])
    bm['주문시각'] = pd.to_datetime(bm['주문시각'].str[:10])

    nw = df_in_dates(nw, dates)
    bm = df_in_dates(bm, dates)
    
    index1 = pd.MultiIndex.from_product([['샐러드', '메인추가'], ['목살', '닭가슴살', '숲속', '연어']])
    index2 = pd.MultiIndex.from_tuples([('샐러드', '이너프'),('extra','고구마'),('extra','계란'),('드레싱','발사믹'),('드레싱','오리엔탈'),('드레싱','렌치')])
    columns = ['배달의민족', '키오스크', '챗봇', '현금', '총합', '비율']

    frame = pd.DataFrame(None, index=index1, columns=columns)
    frame = frame + pd.DataFrame(None, index=index2, columns=columns)
    frame.fillna(0, inplace=True)
    frame = frame.sort_index(ascending=False)


    def fill_stats(*dfs):
        df = frame.copy()
        method = None
        for data in dfs:
            for idx, row in data.iterrows():
                if row['결제방법'] == '바로결제':
                    method = '배달의민족'
                elif row['결제방법'] == '만나서결제':
                    method = '현금'
                elif row['결제방법'] == 'onsite':
                    method = '키오스크'

                # 샐러드 칼럼
                for item in row['항목'].split(', '):
                    if '이너프' in item:
                        df.loc[('샐러드', '이너프'), method] += 1
                    elif '목살' in item:
                        df.loc[('샐러드', '목살'), method] += 1
                    elif '닭가슴살' in item:
                        df.loc[('샐러드', '닭가슴살'), method] += 1
                    elif '숲속' in item:
                        df.loc[('샐러드', '숲속'), method] += 1
                    elif '연어' in item:
                        df.loc[('샐러드', '연어'), method] += 1

                # 메인추가, extra 칼럼
                if type(row['추가선택']) != float:
                    for item in row['추가선택'].split(', '):
                        if '고구마' in item:
                            if 'X' in item:
                                df.loc[('extra', '고구마'), method] -= 1
                            else:
                                df.loc[('extra', '고구마'), method] += 1
                        elif '계란' in item:
                            if 'X' in item:
                                df.loc[('extra', '계란'), method] -= 1
                            else:
                                df.loc[('extra', '계란'), method] += 1
                        elif '목살' in item:
                            if 'X' in item:
                                df.loc[('메인추가', '목살'), method] -= 1
                            else:
                                df.loc[('메인추가', '목살'), method] += 1
                        elif '닭가슴살' in item:
                            if 'X' in item:
                                df.loc[('메인추가', '닭가슴살'), method] -= 1
                            else:
                                df.loc[('메인추가', '닭가슴살'), method] += 1
                        elif '숲속' in item:
                            if 'X' in item:
                                df.loc[('메인추가', '숲속'), method] -= 1
                            else:
                                df.loc[('메인추가', '숲속'), method] += 1
                        elif '연어' in item:
                            if 'X' in item:
                                df.loc[('메인추가', '연어'), method] -= 1
                            else:
                                df.loc[('메인추가', '연어'), method] += 1

                # 드레싱 칼럼
                if type(row['드레싱']) != float:
                    for item in row['드레싱'].split(', '):
                        if '발사믹' in item:
                            if 'X' in item:
                                df.loc[('드레싱', '발사믹'), method] -= 1
                            else:
                                df.loc[('드레싱', '발사믹'), method] += 1
                        elif '오리엔탈' in item:
                            if 'X' in item:
                                df.loc[('드레싱', '오리엔탈'), method] -= 1
                            else:
                                df.loc[('드레싱', '오리엔탈'), method] += 1
                        elif '렌치' in item:
                            if 'X' in item:
                                df.loc[('드레싱', '렌치'), method] -= 1
                            else:
                                df.loc[('드레싱', '렌치'), method] += 1

        # 총합 칼럼
        df['총합'] = df.sum(axis=1)
        # 비율 칼럼
        salads = df.loc['샐러드', '총합'].sum()
        toppings = df.loc['메인추가', '총합'].sum()
        extras = df.loc['extra', '총합'].sum()
        dressings = df.loc['드레싱', '총합'].sum()
        for idx in df.index:
            pair = (idx[0], idx[1])
            if idx[0] == '샐러드':
                df.loc[pair, '비율'] = f"{int((df.loc[pair, '총합'] / salads) * 100)} %"
            elif idx[0] == '드레싱':
                df.loc[pair, '비율'] = f"{int((df.loc[pair, '총합'] / dressings) * 100)} %"
            elif idx[0] == '메인추가':
                df.loc[pair, '비율'] = f"{int((df.loc[pair, '총합'] / toppings) * 100)} %"
            elif idx[0] == 'extra':
                df.loc[pair, '비율'] = f"{int((df.loc[pair, '총합'] / extras) * 100)} %"
        return df

    menu_stats = fill_stats(bm, nw)
    menu_stats.to_csv('test.csv', encoding='utf-8-sig')
    menu_stats = pd.read_csv('test.csv', encoding='utf-8-sig')
    return menu_stats

if __name__ == '__main__':
    mn = menu_st(['2020-08-25', '2020-08-26'])
    print(mn.shape)
    print(mn)
# Out:
# (14, 8)
#    Unnamed: 0 Unnamed: 1  배달의민족  키오스크  챗봇  현금   총합     비율
# 0         샐러드        이너프     19    44   0   2   65   21 %
# 1         샐러드         연어     10    40   0   0   50   16 %
# 2         샐러드         숲속      7    28   0   4   39   12 %
# 3         샐러드         목살     20    68   0   4   92   29 %
# 4         샐러드       닭가슴살     11    51   0   1   63   20 %
# 5        메인추가         연어      0     0   0   0    0    0 %
# 6        메인추가         숲속      8     3   0   2   13   33 %
# 7        메인추가         목살      5     9   0   1   15   38 %
# 8        메인추가       닭가슴살      1     9   0   1   11   28 %
# 9         드레싱       오리엔탈     30    74   0   5  109   39 %
# 10        드레싱        발사믹     11    71   0   1   83   29 %
# 11        드레싱         렌치     23    61   0   3   87   31 %
# 12      extra        고구마     13    46   0   3   62  100 %
# 13      extra         계란      0     0   0   0    0    0 %

# %%
n1 = None
for i in range(len(mn)):
    val = mn.iloc[i]['Unnamed: 0']
    if val != n1:
        n1 = val
    else:
        mn.iloc[i, 0] = None
mn.rename(columns={'Unnamed: 0':'종류',
                                 'Unnamed: 1':'메뉴'})
# Out:
#        종류    메뉴  배달의민족  키오스크  챗봇  현금   총합     비율
# 0     샐러드   이너프     19    44   0   2   65   21 %
# 1    None    연어     10    40   0   0   50   16 %
# 2    None    숲속      7    28   0   4   39   12 %
# 3    None    목살     20    68   0   4   92   29 %
# 4    None  닭가슴살     11    51   0   1   63   20 %
# 5    메인추가    연어      0     0   0   0    0    0 %
# 6    None    숲속      8     3   0   2   13   33 %
# 7    None    목살      5     9   0   1   15   38 %
# 8    None  닭가슴살      1     9   0   1   11   28 %
# 9     드레싱  오리엔탈     30    74   0   5  109   39 %
# 10   None   발사믹     11    71   0   1   83   29 %
# 11   None    렌치     23    61   0   3   87   31 %
# 12  extra   고구마     13    46   0   3   62  100 %
# 13   None    계란      0     0   0   0    0    0 %

# %%
for i in range(n):
    items = []
    extra = []
    dr = []
    temp = df.iloc[i]['항목']
    for x in temp:
        for k in range(x['quantity']):
            if '추가' in x['name']:
                dr.append(x['name'].split(" 추가")[0][2:])
            else:
                items.append(x['name'])
        options = x['options']
        for k in options:
            if k['group'] == "추가선택":
                for y in k['items']:
                    for q in range(y['quantity']):
                        extra.append(y['name'].split(" 추가")[0])
            if k['group'] == "드레싱 선택":
                for y in k['items']:
                    for q in range(y['quantity']):
                        dr.append(y['name'].split()[0])

    df.iloc[i, 3] = ', '.join(items)

    df.loc[i, '추가선택'] = ', '.join(extra)
    df.loc[i, '드레싱'] = ', '.join(dr)

df['결제금액'] = df['주문금액'] + df['배달팁']
df['실제배달료'] = None
cols = [ '주문번호', '수령방법', '결제방법', '항목', '추가선택', '드레싱', '서비스타입', '주문금액', '배달팁', '결제금액', '주문시각',
       '접수시각', '배달시각', '주소', '요청사항', '배달요청사항', '실제배달료']
df = df[cols]

df
# Out:
#           주문번호 수령방법   결제방법                                    항목  \
# 0   B0QV00VUW3   배달   바로결제                       이너프 샐러드, 목살 샐러드
# 1   B0QV00UXYV   배달   바로결제                       이너프 샐러드, 목살 샐러드
# 2   B0QV00UJL6   배달   바로결제                                목살 샐러드
# 3   B0QV00TZKN   배달  만나서결제                       이너프 샐러드, 숲속 샐러드
# 4   B0QV00SCT5   배달   바로결제                      목살 샐러드, 훈제연어 샐러드
# 5   B0QV00SBL8   배달   바로결제                       이너프 샐러드, 목살 샐러드
# 6   B0QV00RYXY   배달   바로결제                              닭가슴살 샐러드
# 7   B0QV00RHJY   배달   바로결제                    닭가슴살 샐러드, 훈제연어 샐러드
# 8   B0QV00QZLJ   배달   바로결제                     이너프 샐러드, 닭가슴살 샐러드
# 9   B0QV00Q6OE   배달   바로결제                       목살 샐러드, 이너프 샐러드
# 10  B0QV00ODME   배달   바로결제                      숲속 샐러드, 훈제연어 샐러드
