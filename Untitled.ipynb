# %%
import json
import pandas as pd
with open('data/2020-08-25.json', 'r', encoding='UTF-8')as file:
    x = json.load(file)

df = pd.DataFrame(x)

df.columns
# Out:
# Index(['orderNo', 'status', 'serviceType', 'deliveryType', 'purchaseType',
#        'reservation', 'payAmount', 'discountAmount', 'orderAmount',
#        'menuDiscountAmount', 'orderDatetime', 'acceptDatetime',
#        'arriveDatetime', 'closedDatetime', 'charge', 'shop', 'items',
#        'payments', 'discounts', 'orderer', 'memo', 'memos', 'card', 'cash'],
#       dtype='object')

# %%
for i in range(len(df)):
    print(df['items'][i])
# Out:
# [{'name': '이너프 샐러드', 'price': 4300, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 4300, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '렌치 드레싱', 'price': 0, 'quantity': 1}]}]}, {'name': '목살 샐러드', 'price': 6400, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 6400, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '렌치 드레싱', 'price': 0, 'quantity': 1}]}]}]
# [{'name': '이너프 샐러드', 'price': 4300, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 4300, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '렌치 드레싱', 'price': 0, 'quantity': 1}]}]}, {'name': '목살 샐러드', 'price': 6400, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 6400, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}]}]
# [{'name': '목살 샐러드', 'price': 11800, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 6400, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}, {'group': '추가선택', 'items': [{'name': '목살 (100g) 추가', 'price': 2600, 'quantity': 1}, {'name': '숲속토핑 (110g) 추가', 'price': 2100, 'quantity': 1}, {'name': '고구마 (50g)', 'price': 700, 'quantity': 1}]}]}, {'name': '[ 렌치 추가 ]', 'price': 500, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 500, 'quantity': 1}]}]}]
# [{'name': '이너프 샐러드', 'price': 5000, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 4300, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '드레싱 X', 'price': 0, 'quantity': 1}]}, {'group': '추가선택', 'items': [{'name': '고구마 (50g) 추가', 'price': 700, 'quantity': 1}]}]}, {'name': '숲속 샐러드', 'price': 5900, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 5900, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}]}]
# [{'name': '목살 샐러드', 'price': 6400, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 6400, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '발사믹 드레싱', 'price': 0, 'quantity': 1}]}]}, {'name': '훈제연어 샐러드', 'price': 6900, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 6900, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}]}]
# [{'name': '이너프 샐러드', 'price': 5000, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 4300, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}, {'group': '추가선택', 'items': [{'name': '고구마 (50g) 추가', 'price': 700, 'quantity': 1}]}]}, {'name': '목살 샐러드', 'price': 8500, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 6400, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}, {'group': '추가선택', 'items': [{'name': '숲속토핑 (110g) 추가', 'price': 2100, 'quantity': 1}]}]}]
# [{'name': '닭가슴살 샐러드', 'price': 11300, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 5900, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '렌치 드레싱', 'price': 0, 'quantity': 1}]}, {'group': '추가선택', 'items': [{'name': '닭가슴살 (100g) 추가', 'price': 2100, 'quantity': 1}, {'name': '숲속토핑 (110g) 추가', 'price': 2100, 'quantity': 1}, {'name': '고구마 (50g)', 'price': 700, 'quantity': 1}, {'name': '삶은 달걀 추가', 'price': 500, 'quantity': 1}]}]}, {'name': '[ 렌치 추가 ]', 'price': 500, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 500, 'quantity': 1}]}]}]
# [{'name': '닭가슴살 샐러드', 'price': 6600, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 5900, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}, {'group': '추가선택', 'items': [{'name': '고구마 (50g)', 'price': 700, 'quantity': 1}]}]}, {'name': '훈제연어 샐러드', 'price': 6900, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 6900, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '렌치 드레싱', 'price': 0, 'quantity': 1}]}]}]
# [{'name': '이너프 샐러드', 'price': 4300, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 4300, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '렌치 드레싱', 'price': 0, 'quantity': 1}]}]}, {'name': '닭가슴살 샐러드', 'price': 5900, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 5900, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '렌치 드레싱', 'price': 0, 'quantity': 1}]}]}]
# [{'name': '목살 샐러드', 'price': 6400, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 6400, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}]}, {'name': '이너프 샐러드', 'price': 4300, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 4300, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}]}]
# [{'name': '숲속 샐러드', 'price': 5900, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 5900, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}]}, {'name': '훈제연어 샐러드', 'price': 6900, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 6900, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '렌치 드레싱', 'price': 0, 'quantity': 1}]}]}]
# [{'name': '목살 샐러드', 'price': 6400, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 6400, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}]}, {'name': '이너프 샐러드', 'price': 4300, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 4300, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}]}]
# [{'name': '이너프 샐러드', 'price': 5000, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 4300, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '발사믹 드레싱', 'price': 0, 'quantity': 1}]}, {'group': '추가선택', 'items': [{'name': '고구마 (50g) 추가', 'price': 700, 'quantity': 1}]}]}, {'name': '닭가슴살 샐러드', 'price': 5900, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 5900, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '발사믹 드레싱', 'price': 0, 'quantity': 1}]}]}]
# [{'name': '숲속 샐러드', 'price': 8500, 'discount': 0, 'quantity': 2, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 5900, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}, {'group': '추가선택', 'items': [{'name': '목살 (100g) 추가', 'price': 2600, 'quantity': 1}]}]}]
# [{'name': '이너프 샐러드', 'price': 5000, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 4300, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}, {'group': '추가선택', 'items': [{'name': '고구마 (50g) 추가', 'price': 700, 'quantity': 1}]}]}, {'name': '이너프 샐러드', 'price': 5000, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 4300, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '렌치 드레싱', 'price': 0, 'quantity': 1}]}, {'group': '추가선택', 'items': [{'name': '고구마 (50g) 추가', 'price': 700, 'quantity': 1}]}]}]
# [{'name': '목살 샐러드', 'price': 9000, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 6400, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '렌치 드레싱', 'price': 0, 'quantity': 1}]}, {'group': '추가선택', 'items': [{'name': '목살 (100g) 추가', 'price': 2600, 'quantity': 1}]}]}, {'name': '숲속 샐러드', 'price': 5900, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 5900, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}]}]
# [{'name': '목살 샐러드', 'price': 9000, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 6400, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '렌치 드레싱', 'price': 0, 'quantity': 1}]}, {'group': '추가선택', 'items': [{'name': '숲속토핑 (110g) 추가', 'price': 2100, 'quantity': 1}, {'name': '삶은 달걀 추가', 'price': 500, 'quantity': 1}]}]}, {'name': '목살 샐러드', 'price': 9200, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 6400, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '발사믹 드레싱', 'price': 0, 'quantity': 1}]}, {'group': '추가선택', 'items': [{'name': '닭가슴살 (100g) 추가', 'price': 2100, 'quantity': 1}, {'name': '고구마 (50g)', 'price': 700, 'quantity': 1}]}]}, {'name': '목살 샐러드', 'price': 8500, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 6400, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '렌치 드레싱', 'price': 0, 'quantity': 1}]}, {'group': '추가선택', 'items': [{'name': '숲속토핑 (110g) 추가', 'price': 2100, 'quantity': 1}]}]}]
# [{'name': '훈제연어 샐러드', 'price': 6900, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 6900, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}]}, {'name': '목살 샐러드', 'price': 6400, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 6400, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}]}]
# [{'name': '이너프 샐러드', 'price': 5000, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 4300, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}, {'group': '추가선택', 'items': [{'name': '고구마 (50g) 추가', 'price': 700, 'quantity': 1}]}]}, {'name': '훈제연어 샐러드', 'price': 7600, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 6900, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}, {'group': '추가선택', 'items': [{'name': '고구마 (50g)', 'price': 700, 'quantity': 1}]}]}]
# [{'name': '닭가슴살 샐러드', 'price': 8000, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 5900, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '발사믹 드레싱', 'price': 0, 'quantity': 1}]}, {'group': '추가선택', 'items': [{'name': '숲속토핑 (110g) 추가', 'price': 2100, 'quantity': 1}]}]}, {'name': '목살 샐러드', 'price': 8500, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 6400, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}, {'group': '추가선택', 'items': [{'name': '숲속토핑 (110g) 추가', 'price': 2100, 'quantity': 1}]}]}, {'name': '닭가슴살 샐러드', 'price': 8000, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 5900, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}, {'group': '추가선택', 'items': [{'name': '숲속토핑 (110g) 추가', 'price': 2100, 'quantity': 1}]}]}, {'name': '닭가슴살 샐러드', 'price': 10600, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 5900, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}, {'group': '추가선택', 'items': [{'name': '숲속토핑 (110g) 추가', 'price': 2100, 'quantity': 1}, {'name': '목살 (100g) 추가', 'price': 2600, 'quantity': 1}]}]}]
# [{'name': '훈제연어 샐러드', 'price': 6900, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 6900, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '렌치 드레싱', 'price': 0, 'quantity': 1}]}]}, {'name': '목살 샐러드', 'price': 6400, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 6400, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}]}]
# [{'name': '훈제연어 샐러드', 'price': 6900, 'discount': 0, 'quantity': 2, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 6900, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '렌치 드레싱', 'price': 0, 'quantity': 1}]}]}]
# [{'name': '닭가슴살 샐러드', 'price': 6600, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 5900, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '렌치 드레싱', 'price': 0, 'quantity': 1}]}, {'group': '추가선택', 'items': [{'name': '고구마 (50g)', 'price': 700, 'quantity': 1}]}]}, {'name': '닭가슴살 샐러드', 'price': 6600, 'discount': 0, 'quantity': 1, 'options': [{'group': '가격', 'items': [{'name': '', 'price': 5900, 'quantity': 1}]}, {'group': '드레싱 선택', 'items': [{'name': '오리엔탈 드레싱', 'price': 0, 'quantity': 1}]}, {'group': '추가선택', 'items': [{'name': '고구마 (50g)', 'price': 700, 'quantity': 1}]}]}]

# %%
for i in range(len(df)):
    print(df['shop'][i])
# Out:
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}
# {'shopNo': '13083364', 'name': '이너프샐러드', 'tel': '05078865254', 'categoryCode': '7'}

# %%
for i in range(len(df)):
    print(df['charge'][i])
# Out:
# {'deliveryTip': 3000, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3000, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3500, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 5000, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 4000, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3500, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 4500, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3000, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3000, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3500, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3000, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3000, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3500, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3000, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3000, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3500, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3500, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3000, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3000, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3500, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3000, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 4500, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3500, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}

# %%
df.columns
# Out:
# Index(['orderNo', 'status', 'serviceType', 'deliveryType', 'purchaseType',
#        'reservation', 'payAmount', 'discountAmount', 'orderAmount',
#        'menuDiscountAmount', 'orderDatetime', 'acceptDatetime',
#        'arriveDatetime', 'closedDatetime', 'charge', 'shop', 'items',
#        'payments', 'discounts', 'orderer', 'memo', 'memos', 'card', 'cash'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['orderNo', 'status', 'serviceType', 'deliveryType', 'purchaseType',
#        'reservation', 'payAmount', 'discountAmount', 'orderAmount',
#        'menuDiscountAmount', 'orderDatetime', 'acceptDatetime',
#        'arriveDatetime', 'closedDatetime', 'charge', 'shop', 'items',
#        'payments', 'discounts', 'orderer', 'memo', 'memos', 'card', 'cash'],
#       dtype='object')

# %%
cols = ['orderNo',
        'deliveryType',
        'purchaseType',
        'items',
        'serviceType',
        'orderAmount',
        'charge',
        'payAmount',
        'orderDatetime',
        'acceptDatetime',
       'arriveDatetime',
         'orderer',
        'memo']

df = df[cols]

# %%
df.rename(columns = {
    'orderNo' : '주문번호', 'serviceType' : '서비스타입',
    'deliveryType' : "수령방법", 'purchaseType' : '결제방법',
    'payAmount' : '결제금액', 'orderAmount' : '주문금액',
        'orderDatetime' : "주문시각", 'acceptDatetime' : "접수시각",
       'arriveDatetime' : "배달시각", 'charge' : "배달팁", 'items' : "항목",
 'orderer' : "주소", 'memo' : '요청사항'}, inplace = True)

# %%
df.head()
# Out:
#          주문번호      수령방법  결제방법  \
# 0  B0QV00VUW3  DELIVERY  BARO
# 1  B0QV00UXYV  DELIVERY  BARO
# 2  B0QV00UJL6  DELIVERY  BARO
# 3  B0QV00TZKN  DELIVERY  MEET
# 4  B0QV00SCT5  DELIVERY  BARO
#
#                                                   항목   서비스타입   주문금액  \
# 0  [{'name': '이너프 샐러드', 'price': 4300, 'discount'...  BAEMIN  10700
# 1  [{'name': '이너프 샐러드', 'price': 4300, 'discount'...  BAEMIN  10700
# 2  [{'name': '목살 샐러드', 'price': 11800, 'discount'...  BAEMIN  12300
# 3  [{'name': '이너프 샐러드', 'price': 5000, 'discount'...  BAEMIN  10900
# 4  [{'name': '목살 샐러드', 'price': 6400, 'discount':...  BAEMIN  13300
#
#                                                  배달팁   결제금액  \
# 0  {'deliveryTip': 3000, 'takeoutDiscountAmount':...  13700
# 1  {'deliveryTip': 3000, 'takeoutDiscountAmount':...  13700
# 2  {'deliveryTip': 3500, 'takeoutDiscountAmount':...  15800
# 3  {'deliveryTip': 5000, 'takeoutDiscountAmount':...  15900
# 4  {'deliveryTip': 4000, 'takeoutDiscountAmount':...  17300
#
#                   주문시각                 접수시각                 배달시각  \
# 0  2020-08-25 17:52:25  2020-08-25 17:54:12  2020-08-25 18:54:12
# 1  2020-08-25 17:43:39  2020-08-25 17:44:14  2020-08-25 18:44:14
# 2  2020-08-25 17:39:53  2020-08-25 17:40:31  2020-08-25 18:40:31
# 3  2020-08-25 17:32:21  2020-08-25 17:32:30  2020-08-25 18:32:30
# 4  2020-08-25 17:15:12  2020-08-25 17:16:48  2020-08-25 18:16:48
#
#                                                   주소  \
# 0  {'tel': None, 'safetyTel': None, 'oldAddress':...
# 1  {'tel': None, 'safetyTel': None, 'oldAddress':...
# 2  {'tel': None, 'safetyTel': None, 'oldAddress':...
# 3  {'tel': None, 'safetyTel': None, 'oldAddress':...
# 4  {'tel': None, 'safetyTel': None, 'oldAddress':...
#
#                                                 요청사항
# 0                                   {'delivery': []}
# 1                                   {'delivery': []}
# 2  {'delivery': ['강낭콩,올리브,할라피뇨 다 빼주세요 :) 양파 양상추 옥...
# 3                                   {'delivery': []}
# 4  {'delivery': ['안녕하세요 혹시 많이시켜서 쟁여두고먹으려고하는데 유통기한...

# %%
df['결제방법'].describe()
# Out:
# count       23
# unique       2
# top       BARO
# freq        20
# Name: 결제방법, dtype: object

# %%
df.loc[df['서비스타입'] == "BAEMIN", "서비스타입"] = "배민"
df.loc[df['수령방법'] == "DELIVERY", "수령방법"] = "배달"
df.loc[df['결제방법'] == "BARO", "결제방법"] = "바로결제"
df.loc[df['결제방법'] == "MEET", "결제방법"] = "만나서결제"
df.head()
# Out:
#          주문번호 수령방법   결제방법                                                 항목  \
# 0  B0QV00VUW3   배달   바로결제  [{'name': '이너프 샐러드', 'price': 4300, 'discount'...
# 1  B0QV00UXYV   배달   바로결제  [{'name': '이너프 샐러드', 'price': 4300, 'discount'...
# 2  B0QV00UJL6   배달   바로결제  [{'name': '목살 샐러드', 'price': 11800, 'discount'...
# 3  B0QV00TZKN   배달  만나서결제  [{'name': '이너프 샐러드', 'price': 5000, 'discount'...
# 4  B0QV00SCT5   배달   바로결제  [{'name': '목살 샐러드', 'price': 6400, 'discount':...
#
#   서비스타입   주문금액                                                배달팁   결제금액  \
# 0    배민  10700  {'deliveryTip': 3000, 'takeoutDiscountAmount':...  13700
# 1    배민  10700  {'deliveryTip': 3000, 'takeoutDiscountAmount':...  13700
# 2    배민  12300  {'deliveryTip': 3500, 'takeoutDiscountAmount':...  15800
# 3    배민  10900  {'deliveryTip': 5000, 'takeoutDiscountAmount':...  15900
# 4    배민  13300  {'deliveryTip': 4000, 'takeoutDiscountAmount':...  17300
#
#                   주문시각                 접수시각                 배달시각  \
# 0  2020-08-25 17:52:25  2020-08-25 17:54:12  2020-08-25 18:54:12
# 1  2020-08-25 17:43:39  2020-08-25 17:44:14  2020-08-25 18:44:14
# 2  2020-08-25 17:39:53  2020-08-25 17:40:31  2020-08-25 18:40:31
# 3  2020-08-25 17:32:21  2020-08-25 17:32:30  2020-08-25 18:32:30
# 4  2020-08-25 17:15:12  2020-08-25 17:16:48  2020-08-25 18:16:48
#
#                                                   주소  \
# 0  {'tel': None, 'safetyTel': None, 'oldAddress':...
# 1  {'tel': None, 'safetyTel': None, 'oldAddress':...
# 2  {'tel': None, 'safetyTel': None, 'oldAddress':...
# 3  {'tel': None, 'safetyTel': None, 'oldAddress':...
# 4  {'tel': None, 'safetyTel': None, 'oldAddress':...
#
#                                                 요청사항
# 0                                   {'delivery': []}
# 1                                   {'delivery': []}
# 2  {'delivery': ['강낭콩,올리브,할라피뇨 다 빼주세요 :) 양파 양상추 옥...
# 3                                   {'delivery': []}
# 4  {'delivery': ['안녕하세요 혹시 많이시켜서 쟁여두고먹으려고하는데 유통기한...

# %%
n = len(df)

for i in range(n):
    df.iloc[i, 6] = df.iloc[i]['배달팁']['deliveryTip']
    
for i in range(n):
    df.iloc[i, 11] = df.iloc[i]['주소']['streetAddress']
for i in range(n):
    df.iloc[i, 12] = ''.join(df.iloc[i]['요청사항']['delivery'])

for i in range(n):
    items = []
    extra = []
    dr = []
    temp = df.iloc[i]['항목']
    for x in temp:
        for k in range(x['quantity']):
            if '추가' in x['name']:
                dr.append(x['name'].split(" 추가")[0][2:])
            else:
                items.append(x['name'])
        options = x['options']
        for k in options:
            if k['group'] == "추가선택":
                for y in k['items']:
                    for q in range(y['quantity']):
                        extra.append(y['name'].split(" 추가")[0])
            if k['group'] == "드레싱 선택" : 
                for y in k['items']:
                    for q in range(y['quantity']):
                        dr.append(y['name'].split()[0])
                    
                    
    df.iloc[i, 3] = ', '.join(items)

    df.loc[i, '추가선택'] = ', '.join(extra)
    df.loc[i, '드레싱'] = ', '.join(dr)
df
# Out:
#           주문번호 수령방법   결제방법                                    항목 서비스타입   주문금액  \
# 0   B0QV00VUW3   배달   바로결제                       이너프 샐러드, 목살 샐러드    배민  10700
# 1   B0QV00UXYV   배달   바로결제                       이너프 샐러드, 목살 샐러드    배민  10700
# 2   B0QV00UJL6   배달   바로결제                                목살 샐러드    배민  12300
# 3   B0QV00TZKN   배달  만나서결제                       이너프 샐러드, 숲속 샐러드    배민  10900
# 4   B0QV00SCT5   배달   바로결제                      목살 샐러드, 훈제연어 샐러드    배민  13300
# 5   B0QV00SBL8   배달   바로결제                       이너프 샐러드, 목살 샐러드    배민  13500
# 2                   목살 (100g), 숲속토핑 (110g), 고구마 (50g)               오리엔탈, 렌치
# 3                                           고구마 (50g)              드레싱, 오리엔탈
# 4                                                                  발사믹, 오리엔탈
# 5                              고구마 (50g), 숲속토핑 (110g)             오리엔탈, 오리엔탈
# 6          닭가슴살 (100g), 숲속토핑 (110g), 고구마 (50g), 삶은 달걀                 렌치, 렌치
# 7                                           고구마 (50g)               오리엔탈, 렌치
# 8                                                                     렌치, 렌치
# 9                                                                 오리엔탈, 오리엔탈
# 10                                                                  오리엔탈, 렌치
# 11                                                                오리엔탈, 오리엔탈
# 12                                          고구마 (50g)               발사믹, 발사믹
# 13                                          목살 (100g)                   오리엔탈
# 14                               고구마 (50g), 고구마 (50g)               오리엔탈, 렌치
# 15                                          목살 (100g)               렌치, 오리엔탈
# 16  숲속토핑 (110g), 삶은 달걀, 닭가슴살 (100g), 고구마 (50g), 숲속...            렌치, 발사믹, 렌치
# 17                                                                오리엔탈, 오리엔탈
# 18                               고구마 (50g), 고구마 (50g)             오리엔탈, 오리엔탈
# 19  숲속토핑 (110g), 숲속토핑 (110g), 숲속토핑 (110g), 숲속토핑 (1...  발사믹, 오리엔탈, 오리엔탈, 오리엔탈
# 20                                                                  렌치, 오리엔탈
# 21                                                                        렌치
# 22                               고구마 (50g), 고구마 (50g)               렌치, 오리엔탈

# %%
cols = ['주문번호', '수령방법', '결제방법', '항목', '추가선택', '드레싱', '서비스타입', '주문금액', '배달팁', '결제금액', '주문시각',
       '접수시각', '배달시각', '주소', '요청사항']
df = df[cols]
df
# Out:
#           주문번호 수령방법   결제방법                                    항목  \
# 0   B0QV00VUW3   배달   바로결제                       이너프 샐러드, 목살 샐러드
# 1   B0QV00UXYV   배달   바로결제                       이너프 샐러드, 목살 샐러드
# 2   B0QV00UJL6   배달   바로결제                                목살 샐러드
# 3   B0QV00TZKN   배달  만나서결제                       이너프 샐러드, 숲속 샐러드
# 4   B0QV00SCT5   배달   바로결제                      목살 샐러드, 훈제연어 샐러드
# 5   B0QV00SBL8   배달   바로결제                       이너프 샐러드, 목살 샐러드
# 6   B0QV00RYXY   배달   바로결제                              닭가슴살 샐러드
# 7   B0QV00RHJY   배달   바로결제                    닭가슴살 샐러드, 훈제연어 샐러드
# 8   B0QV00QZLJ   배달   바로결제                     이너프 샐러드, 닭가슴살 샐러드
# 9   B0QV00Q6OE   배달   바로결제                       목살 샐러드, 이너프 샐러드
# 10  B0QV00ODME   배달   바로결제                      숲속 샐러드, 훈제연어 샐러드
# 11  B0QV00M0C1   배달   바로결제                       목살 샐러드, 이너프 샐러드
# 12  B0QV00EZGF   배달   바로결제                     이너프 샐러드, 닭가슴살 샐러드
# 13  B0QV00ELD9   배달  만나서결제                        숲속 샐러드, 숲속 샐러드
# 14  B0QV00DV3F   배달   바로결제                      이너프 샐러드, 이너프 샐러드
# 15  B0QV00ACZA   배달   바로결제                        목살 샐러드, 숲속 샐러드
# 16  B0QV00AA5P   배달  만나서결제                목살 샐러드, 목살 샐러드, 목살 샐러드
# 8
# 9
# 10                                         강낭콩빼쥬세요!!!
# 11                                           강낭콩 빼주세요
# 12                              강낭콩. 할라피뇨. 올리브 빼주세요!!
# 13
# 14
# 15                                            (수저포크X)
# 16
# 17
# 18                                            강낭콩빼주세요
# 19                  닭가슴살에 숲속추가한거 한개는 양파랑아몬드빼고 강낭콩더주세요
# 20                                            (수저포크X)
# 21
# 22

# %%
df = pd.read_csv('누적데이터.csv', encoding='utf-8-sig'
                )
df = df.fillna('')

menus = ['이너프 샐러드', '닭가슴살 샐러드', '숲속 샐러드', '목살 샐러드', '훈제연어 샐러드']

temp = list(df['항목'].values)
items = []
for x in temp:
    items.extend(x.split(', '))
    
menu_data = []   
for i in menus:
    menu_data.append(items.count(i))
    
index = pd.MultiIndex.from_product([['항목'], menus])
columns = ['수량']

menu_df = pd.DataFrame(menu_data, index = index, columns = columns)
menu = pd.DataFrame(menu_data, index = menus, columns = columns)



extra = ['숲속토핑 (110g)', '닭가슴살 (100g)', '목살 (100g)', '고구마 (50g)', '삶은 달걀',
        ]
index = pd.MultiIndex.from_product([['추가선택'], extra])
columns = ['수량']

temp = list(df['추가선택'].values)
items = []
for x in temp:
    items.extend(x.split(', '))

extra_data = []   
for i in extra:
    extra_data.append(items.count(i))

index = pd.MultiIndex.from_product([['추가선택'], extra])
columns = ['수량']
extra_df = pd.DataFrame(extra_data, index = index, columns = columns)
extra = pd.DataFrame(extra_data, index = extra, columns = columns)


extra2 = ['발사믹', '렌치', '오리엔탈']
index = pd.MultiIndex.from_product([['드레싱'], extra2])
columns = ['수량']

temp = list(df['드레싱'].values)
items = []
for x in temp:
    items.extend(x.split(', '))

extra2_data = []   
for i in extra2:
    extra2_data.append(items.count(i))

index = pd.MultiIndex.from_product([['드레싱'], extra2])
columns = ['수량']

extra2_df = pd.DataFrame(extra2_data, index = index, columns = columns)
extra2 = pd.DataFrame(extra2_data, index = extra2, columns = columns)

frames = [menu_df, extra_df, extra2_df]
result = pd.concat(frames)
result

# df.reset_index(inplace=True)
# df.loc[df['index1'].duplicated(), 'index1'] = ''
# df.to_csv('mycsv.csv', index=False)
# Out:
#                   수량
# 항목   이너프 샐러드      10
#      닭가슴살 샐러드      3
#      숲속 샐러드        6
#      목살 샐러드       10
#      훈제연어 샐러드      2
# 추가선택 숲속토핑 (110g)   1
#      닭가슴살 (100g)   0
#      목살 (100g)     2
#      고구마 (50g)     3
#      삶은 달걀         3
# 드레싱  발사믹           7
#      렌치            9
#      오리엔탈         11

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams["font.family"] = 'nanummyeongjo'
menu.plot(kind='pie', y = '수량', autopct='%1.2f%%', 
        shadow=True, 
        startangle=90)
plt.title('주메뉴', fontsize=20)
plt.legend()
plt.show()

extra.plot(kind='pie', y = '수량', autopct='%1.2f%%', 
        shadow=True, 
        startangle=90)
plt.title('추가메뉴', fontsize=20)
plt.show()

extra2.plot(kind='pie', y = '수량', autopct='%1.2f%%', 
        shadow=True, 
        startangle=90)
plt.title('드레싱 추가', fontsize=20)
plt.show()
