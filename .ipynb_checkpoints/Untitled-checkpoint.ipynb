# %%
import json
import pandas as pd
with open('test.json', 'r', encoding='UTF-8')as file:
    x = json.load(file)['data']['histories']

df = pd.DataFrame(x)

df
# Out:
#        orderNo  status serviceType deliveryType purchaseType  reservation  \
# 0   B0QV00VUW3  CLOSED      BAEMIN     DELIVERY         BARO        False
# 1   B0QV00UXYV  CLOSED      BAEMIN     DELIVERY         BARO        False
# 2   B0QV00UJL6  CLOSED      BAEMIN     DELIVERY         BARO        False
# 3   B0QV00TZKN  CLOSED      BAEMIN     DELIVERY         MEET        False
# 4   B0QV00SCT5  CLOSED      BAEMIN     DELIVERY         BARO        False
# 5   B0QV00SBL8  CLOSED      BAEMIN     DELIVERY         BARO        False
# 6   B0QV00RYXY  CLOSED      BAEMIN     DELIVERY         BARO        False
# 7   B0QV00RHJY  CLOSED      BAEMIN     DELIVERY         BARO        False
# 8   B0QV00QZLJ  CLOSED      BAEMIN     DELIVERY         BARO        False
# 9   B0QV00Q6OE  CLOSED      BAEMIN     DELIVERY         BARO        False
# 10  B0QV00ODME  CLOSED      BAEMIN     DELIVERY         BARO        False
# 11  B0QV00M0C1  CLOSED      BAEMIN     DELIVERY         BARO        False
# ...

# %%
for i in range(len(df)):
    print(df['items'][i])
# Out:
# [{'name': '이너프 샐러드', 'quantity': 1}, {'name': '목살 샐러드', 'quantity': 1}]
# [{'name': '이너프 샐러드', 'quantity': 1}, {'name': '목살 샐러드', 'quantity': 1}]
# [{'name': '목살 샐러드', 'quantity': 1}, {'name': '[ 렌치 추가 ]', 'quantity': 1}]
# [{'name': '이너프 샐러드', 'quantity': 1}, {'name': '숲속 샐러드', 'quantity': 1}]
# [{'name': '목살 샐러드', 'quantity': 1}, {'name': '훈제연어 샐러드', 'quantity': 1}]
# [{'name': '이너프 샐러드', 'quantity': 1}, {'name': '목살 샐러드', 'quantity': 1}]
# [{'name': '닭가슴살 샐러드', 'quantity': 1}, {'name': '[ 렌치 추가 ]', 'quantity': 1}]
# [{'name': '닭가슴살 샐러드', 'quantity': 1}, {'name': '훈제연어 샐러드', 'quantity': 1}]
# [{'name': '이너프 샐러드', 'quantity': 1}, {'name': '닭가슴살 샐러드', 'quantity': 1}]
# [{'name': '목살 샐러드', 'quantity': 1}, {'name': '이너프 샐러드', 'quantity': 1}]
# [{'name': '숲속 샐러드', 'quantity': 1}, {'name': '훈제연어 샐러드', 'quantity': 1}]
# [{'name': '목살 샐러드', 'quantity': 1}, {'name': '이너프 샐러드', 'quantity': 1}]
# [{'name': '이너프 샐러드', 'quantity': 1}, {'name': '닭가슴살 샐러드', 'quantity': 1}]
# ...

# %%
for i in range(len(df)):
    print(df['shop'][i])
# Out:
# {'shopNo': '13083364', 'categoryCode': '7', 'name': '이너프샐러드'}
# {'shopNo': '13083364', 'categoryCode': '7', 'name': '이너프샐러드'}
# {'shopNo': '13083364', 'categoryCode': '7', 'name': '이너프샐러드'}
# {'shopNo': '13083364', 'categoryCode': '7', 'name': '이너프샐러드'}
# {'shopNo': '13083364', 'categoryCode': '7', 'name': '이너프샐러드'}
# {'shopNo': '13083364', 'categoryCode': '7', 'name': '이너프샐러드'}
# {'shopNo': '13083364', 'categoryCode': '7', 'name': '이너프샐러드'}
# {'shopNo': '13083364', 'categoryCode': '7', 'name': '이너프샐러드'}
# {'shopNo': '13083364', 'categoryCode': '7', 'name': '이너프샐러드'}
# {'shopNo': '13083364', 'categoryCode': '7', 'name': '이너프샐러드'}
# {'shopNo': '13083364', 'categoryCode': '7', 'name': '이너프샐러드'}
# {'shopNo': '13083364', 'categoryCode': '7', 'name': '이너프샐러드'}
# {'shopNo': '13083364', 'categoryCode': '7', 'name': '이너프샐러드'}
# {'shopNo': '13083364', 'categoryCode': '7', 'name': '이너프샐러드'}
# {'shopNo': '13083364', 'categoryCode': '7', 'name': '이너프샐러드'}
# ...

# %%
for i in range(len(df)):
    print(df['charge'][i])
# Out:
# {'deliveryTip': 3000, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3000, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3500, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 5000, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 4000, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3500, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 4500, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3000, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3000, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3500, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3000, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# {'deliveryTip': 3000, 'takeoutDiscountAmount': 0, 'employeeDiscountAmount': 0}
# ...

# %%
df.columns
# Out:
# Index(['orderNo', 'status', 'serviceType', 'deliveryType', 'purchaseType',
#        'reservation', 'payAmount', 'orderAmount', 'discountAmount',
#        'menuDiscountAmount', 'orderDatetime', 'acceptDatetime',
#        'arriveDatetime', 'shop', 'items', 'charge', 'adCampaign'],
#       dtype='object')

# %%
cols = ['orderNo',  'serviceType', 'deliveryType', 'purchaseType',
       'reservation', 'payAmount', 'orderAmount', 'orderDatetime', 'acceptDatetime',
       'arriveDatetime', 'items', 'charge']
df = df[cols]
df
# Out:
#        orderNo serviceType deliveryType purchaseType  reservation  payAmount  \
# 0   B0QV00VUW3      BAEMIN     DELIVERY         BARO        False      13700
# 1   B0QV00UXYV      BAEMIN     DELIVERY         BARO        False      13700
# 2   B0QV00UJL6      BAEMIN     DELIVERY         BARO        False      15800
# 3   B0QV00TZKN      BAEMIN     DELIVERY         MEET        False      15900
# 4   B0QV00SCT5      BAEMIN     DELIVERY         BARO        False      17300
# 5   B0QV00SBL8      BAEMIN     DELIVERY         BARO        False      17000
# 6   B0QV00RYXY      BAEMIN     DELIVERY         BARO        False      16300
# 7   B0QV00RHJY      BAEMIN     DELIVERY         BARO        False      16500
# 8   B0QV00QZLJ      BAEMIN     DELIVERY         BARO        False      13200
# 9   B0QV00Q6OE      BAEMIN     DELIVERY         BARO        False      14200
# 10  B0QV00ODME      BAEMIN     DELIVERY         BARO        False      15800
# ...

# %%
list(df['orderNo'])
# Out:
# ['B0QV00VUW3',
#  'B0QV00UXYV',
#  'B0QV00UJL6',
#  'B0QV00TZKN',
#  'B0QV00SCT5',
#  'B0QV00SBL8',
#  'B0QV00RYXY',
#  'B0QV00RHJY',
#  'B0QV00QZLJ',
#  'B0QV00Q6OE',
#  'B0QV00ODME',
#  'B0QV00M0C1',
#  'B0QV00EZGF',
#  'B0QV00ELD9',
#  'B0QV00DV3F',
#  'B0QV00ACZA',
#  'B0QV00AA5P',
#  'B0QV009Y7U',
#  'B0QV008KMV',
#  'B0QV006L5R',
#  'B0QV006FUW',
#  'B0QV006BSN',
#  'B0QV005W6Y']

# %%
with open('result.json', 'r', encoding='UTF-8')as file:
    x = json.load(file)

df = pd.DataFrame(x)
df
# Out:
#        orderNo  status serviceType deliveryType purchaseType  reservation  \
# 0   B0QW00J96U  CLOSED      BAEMIN     DELIVERY         MEET        False
# 1   B0QW00I3CC  CLOSED      BAEMIN     DELIVERY         BARO        False
# 2   B0QW00HMR4  CLOSED      BAEMIN     DELIVERY         BARO        False
# 3   B0QW00HJBQ  CLOSED      BAEMIN     DELIVERY         MEET        False
# 4   B0QW00GIMX  CLOSED      BAEMIN     DELIVERY         BARO        False
# 5   B0QW00AWTC  CLOSED      BAEMIN     DELIVERY         BARO        False
# 6   B0QW00AQ9U  CLOSED      BAEMIN     DELIVERY         BARO        False
# 7   B0QW009TIN  CLOSED      BAEMIN     DELIVERY         BARO        False
# 8   B0QW0098CJ  CLOSED      BAEMIN     DELIVERY         BARO        False
# 9   B0QW008T8M  CLOSED      BAEMIN     DELIVERY         BARO        False
# 10  B0QW008BVX  CLOSED      BAEMIN     DELIVERY         BARO        False
# 11  B0QW005PY8  CLOSED      BAEMIN     DELIVERY         BARO        False
# ...

# %%
df.columns
# Out:
# Index(['orderNo', 'status', 'serviceType', 'deliveryType', 'purchaseType',
#        'reservation', 'payAmount', 'discountAmount', 'orderAmount',
#        'menuDiscountAmount', 'orderDatetime', 'acceptDatetime',
#        'arriveDatetime', 'closedDatetime', 'charge', 'shop', 'items',
#        'payments', 'discounts', 'orderer', 'memo', 'memos', 'card', 'cash'],
#       dtype='object')

# %%
cols = ['orderNo', 'serviceType', 'deliveryType', 'purchaseType', 'payAmount', 'orderAmount',
        'orderDatetime', 'acceptDatetime',
       'arriveDatetime', 'charge', 'items',
       'payments', 'discounts', 'orderer', 'memo', 'memos', 'card', 'cash']

# %%
df['closedDatetime']
# Out:
# 0     2020-08-26 14:05:26
# 1     2020-08-26 14:15:26
# 2     2020-08-26 13:48:38
# 3     2020-08-26 14:03:40
# 4     2020-08-26 13:58:12
# 5     2020-08-26 12:29:48
# 6     2020-08-26 13:04:55
# 7     2020-08-26 12:21:05
# 8     2020-08-26 12:12:00
# 9     2020-08-26 12:22:28
# 10    2020-08-26 12:07:12
# 11    2020-08-26 11:46:10
# 12    2020-08-26 11:50:20
# 13    2020-08-26 11:41:39
# Name: closedDatetime, dtype: object

# %%
df['cash']
# Out:
# 0     False
# 1      True
# 2      True
# 3     False
# 4     False
# 5      True
# 6     False
# 7      True
# 8      True
# 9      True
# 10     True
# 11    False
# 12     True
# 13    False
# Name: cash, dtype: bool
